# %%
import wordcloud
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import display
import fileupload
import io
import sys

import urllib.request
file_contents = urllib.request.urlopen('https://storage.googleapis.com/datsets/howtowinfriendsandinfulencepeople.txt').read().decode('utf-8')

def calculate_frequencies(file_contents):
    # Here is a list of punctuations and uninteresting words you can use to process your text
    punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    uninteresting_words = ["the", "a", "to", "if", "is", "it", "of", "and", "or", "an", "as", "i", "me", "my", \
    "we", "our", "ours", "you", "your", "yours", "he", "she", "him", "his", "her", "hers", "its", "they", "them", \
    "their", "what", "which", "who", "whom", "this", "that", "am", "are", "was", "were", "be", "been", "being", \
    "have", "has", "had", "do", "does", "did", "but", "at", "by", "with", "from", "here", "when", "where", "how", \
    "all", "any", "both", "each", "few", "more", "some", "such", "no", "nor", "too", "very", "can", "will", "just",\
    "in", "for", "on", "so", "not", "then", "one", "new", "out", "get", "would", "about", "like", "only", "could", \
    "than", "up", "make", "made"]
    
    # LEARNER CODE START HERE
    frequency={}
    final_text=[]
    
    
    words=file_contents.split()
    for word in words:
        wrd=word.lower()
        if(wrd.isalpha() and wrd not in uninteresting_words):
            final_text.append(wrd)
            
    for word in final_text:
        if word not in frequency:
            frequency[word]=1
        else:
            frequency[word]+=1
    
    #wordcloud
    cloud = wordcloud.WordCloud()
    cloud.generate_from_frequencies(frequency)
    return cloud.to_array()

# Display your wordcloud image

myimage = calculate_frequencies(file_contents)
plt.imshow(myimage, interpolation = 'nearest')
plt.axis('off')
plt.show()
